# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from typing import Iterator, MutableSequence, Optional, Sequence, Tuple

import google.cloud.documentai_v1 as docai
from tabulate import tabulate

PROJECT_ID = os.getenv("PROJECT_ID", "")
API_LOCATION = os.getenv("API_LOCATION", "")


os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = './docextraction-440803-2193a2f4556f.json'
assert PROJECT_ID, "PROJECT_ID is undefined"
assert API_LOCATION in ("us", "eu"), "API_LOCATION is incorrect"

# %%
# Test processors
document_ocr_display_name = "document-ocr"
form_parser_display_name = "form-parser"

# %%
test_processor_display_names_and_types = (
    (document_ocr_display_name, "OCR_PROCESSOR"),
    (form_parser_display_name, "FORM_PARSER_PROCESSOR"),
)

# %%
def get_client() -> docai.DocumentProcessorServiceClient:
    client_options = {"api_endpoint": f"{API_LOCATION}-documentai.googleapis.com"}
    return docai.DocumentProcessorServiceClient(client_options=client_options)

# %%
def get_parent(client: docai.DocumentProcessorServiceClient) -> str:
    return client.common_location_path(PROJECT_ID, API_LOCATION)

# %%
def fetch_processor_types() -> MutableSequence[docai.ProcessorType]:
    client, parent = get_client_and_parent()
    response = client.fetch_processor_types(parent=parent)

    return response.processor_types

def print_processor_types(processor_types: Sequence[docai.ProcessorType]):
    def sort_key(pt):
        return (not pt.allow_creation, pt.category, pt.type_)

    sorted_processor_types = sorted(processor_types, key=sort_key)
    data = processor_type_tabular_data(sorted_processor_types)
    headers = next(data)
    colalign = next(data)

    print(tabulate(data, headers, tablefmt="pretty", colalign=colalign))
    print(f"→ Processor types: {len(sorted_processor_types)}")

def processor_type_tabular_data(
    processor_types: Sequence[docai.ProcessorType],
) -> Iterator[Tuple[str, str, str, str]]:
    def locations(pt):
        return ", ".join(sorted(loc.location_id for loc in pt.available_locations))

    yield ("type", "category", "allow_creation", "locations")
    yield ("left", "left", "left", "left")
    if not processor_types:
        yield ("-", "-", "-", "-")
        return
    for pt in processor_types:
        yield (pt.type_, pt.category, f"{pt.allow_creation}", locations(pt))
        
def get_client_and_parent() -> Tuple[docai.DocumentProcessorServiceClient, str]:
    client = get_client()
    parent = get_parent(client)
    return client, parent

# %%
processor_types = fetch_processor_types()
print_processor_types(processor_types)
# Out:
# +--------------------------------------+-------------+----------------+-----------------------------------------------------------------------------------------------------------------+
# | type                                 | category    | allow_creation | locations                                                                                                       |
# +--------------------------------------+-------------+----------------+-----------------------------------------------------------------------------------------------------------------+
# | CUSTOM_CLASSIFICATION_PROCESSOR      | CUSTOM      | True           | asia-south1, asia-southeast1, australia-southeast1, eu, europe-west2, europe-west3, northamerica-northeast1, us |
# | CUSTOM_EXTRACTION_PROCESSOR          | CUSTOM      | True           | asia-south1, asia-southeast1, australia-southeast1, eu, europe-west2, europe-west3, northamerica-northeast1, us |
# | CUSTOM_SPLITTING_PROCESSOR           | CUSTOM      | True           | asia-south1, asia-southeast1, australia-southeast1, eu, europe-west2, europe-west3, northamerica-northeast1, us |
# | SUMMARY_PROCESSOR                    | CUSTOM      | True           | us                                                                                                              |
# | FORM_PARSER_PROCESSOR                | GENERAL     | True           | asia-south1, asia-southeast1, australia-southeast1, eu, europe-west2, europe-west3, northamerica-northeast1, us |
# | LAYOUT_PARSER_PROCESSOR              | GENERAL     | True           | eu, us                                                                                                          |
# | OCR_PROCESSOR                        | GENERAL     | True           | asia-south1, asia-southeast1, australia-southeast1, eu, europe-west2, europe-west3, northamerica-northeast1, us |
# | BANK_STATEMENT_PROCESSOR             | SPECIALIZED | True           | eu, us                                                                                                          |
# | EXPENSE_PROCESSOR                    | SPECIALIZED | True           | asia-southeast1, australia-southeast1, eu, northamerica-northeast1, us                                          |
# | FORM_W2_PROCESSOR                    | SPECIALIZED | True           | eu, us                                                                                                          |
# | FORM_W9_PROCESSOR                    | SPECIALIZED | True           | eu, us                                                                                                          |
# | ID_PROOFING_PROCESSOR                | SPECIALIZED | True           | eu, us                                                                                                          |
# | INVOICE_PROCESSOR                    | SPECIALIZED | True           | asia-south1, asia-southeast1, australia-southeast1, eu, northamerica-northeast1, us                             |
# | PAYSTUB_PROCESSOR                    | SPECIALIZED | True           | eu, us                                                                                                          |
# | US_DRIVER_LICENSE_PROCESSOR          | SPECIALIZED | True           | eu, us                                                                                                          |
# | US_PASSPORT_PROCESSOR                | SPECIALIZED | True           | eu, us                                                                                                          |
# | UTILITY_PROCESSOR                    | SPECIALIZED | True           | eu, us                                                                                                          |
# | LENDING_DOCUMENT_SPLIT_PROCESSOR     | SPECIALIZED | False          | eu, us                                                                                                          |
# | PROCUREMENT_DOCUMENT_SPLIT_PROCESSOR | SPECIALIZED | False          | eu, us                                                                                                          |
# +--------------------------------------+-------------+----------------+-----------------------------------------------------------------------------------------------------------------+
# → Processor types: 19

# %%
def create_processor(display_name: str, type: str) -> docai.Processor:
    client, parent = get_client_and_parent()
    processor = docai.Processor(display_name=display_name, type_=type)

    return client.create_processor(parent=parent, processor=processor)

# %%
separator = "=" * 80
for display_name, type in test_processor_display_names_and_types:
    print(separator)
    print(f"Creating {display_name} ({type})...")
    try:
        create_processor(display_name, type)
    except Exception as err:
        print(err)
print(separator)
print("Done")
# Out:
# ================================================================================
# Creating document-ocr (OCR_PROCESSOR)...
# ================================================================================
# Creating form-parser (FORM_PARSER_PROCESSOR)...
# ================================================================================
# Done

# %%
def list_processors() -> MutableSequence[docai.Processor]:
    client, parent = get_client_and_parent()
    response = client.list_processors(parent=parent)

    return list(response.processors)

def print_processors(processors: Optional[Sequence[docai.Processor]] = None):
    def sort_key(processor):
        return processor.display_name

    if processors is None:
        processors = list_processors()
    sorted_processors = sorted(processors, key=sort_key)
    data = processor_tabular_data(sorted_processors)
    headers = next(data)
    colalign = next(data)

    print(tabulate(data, headers, tablefmt="pretty", colalign=colalign))
    print(f"→ Processors: {len(sorted_processors)}")

def processor_tabular_data(
    processors: Sequence[docai.Processor],
) -> Iterator[Tuple[str, str, str]]:
    yield ("display_name", "type", "state")
    yield ("left", "left", "left")
    if not processors:
        yield ("-", "-", "-")
        return
    for processor in processors:
        yield (processor.display_name, processor.type_, processor.state.name)

# %%
processors = list_processors()
print_processors(processors)
# Out:
# +--------------+-----------------------+---------+
# | display_name | type                  | state   |
# +--------------+-----------------------+---------+
# | doc OCR      | OCR_PROCESSOR         | ENABLED |
# | document-ocr | OCR_PROCESSOR         | ENABLED |
# | form-parser  | FORM_PARSER_PROCESSOR | ENABLED |
# +--------------+-----------------------+---------+
# → Processors: 3

# %%
def get_processor(
    display_name: str,
    processors: Optional[Sequence[docai.Processor]] = None,
) -> Optional[docai.Processor]:
    if processors is None:
        processors = list_processors()
    for processor in processors:
        if processor.display_name == display_name:
            return processor
    return None

# %%
processor = get_processor(document_ocr_display_name, processors)

assert processor is not None
print(processor)
# Out:
# name: "projects/712357922075/locations/us/processors/5d98407fb8df954c"
# type_: "OCR_PROCESSOR"
# display_name: "document-ocr"
# state: ENABLED
# process_endpoint: "https://us-documentai.googleapis.com/v1/projects/712357922075/locations/us/processors/5d98407fb8df954c:process"
# create_time {
#   seconds: 1730782625
#   nanos: 516346000
# }
# default_processor_version: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained-ocr-v2.0-2023-06-02"
# processor_version_aliases {
#   alias: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained"
#   processor_version: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained-ocr-v1.0-2020-09-23"
# }
# processor_version_aliases {
#   alias: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained-next"
#   processor_version: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained-ocr-v1.1-2022-09-12"
# }
# processor_version_aliases {
#   alias: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/rc"
#   processor_version: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained-ocr-v2.1-2024-08-07"
# }
# processor_version_aliases {
#   alias: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/stable"
#   processor_version: "projects/712357922075/locations/us/processors/5d98407fb8df954c/processorVersions/pretrained-ocr-v2.0-2023-06-02"
# }

# %%
# Out:
# 'gsutil' is not recognized as an internal or external command,
# operable program or batch file.

# %%
def process_file(
    processor: docai.Processor,
    file_path: str,
    mime_type: str,
) -> docai.Document:
    client = get_client()
    with open(file_path, "rb") as document_file:
        document_content = document_file.read()
    document = docai.RawDocument(content=document_content, mime_type=mime_type)
    request = docai.ProcessRequest(raw_document=document, name=processor.name)

    response = client.process_document(request)

    return response.document

# %%
processor = get_processor(form_parser_display_name)
assert processor is not None

file_path = "./document-001-115484.out.000.pdf"
mime_type = "application/pdf"

document = process_file(processor, file_path, mime_type)

# %%
document
# Out:
# uri: ""
# mime_type: "application/pdf"
# text: "SHARP\nGL1F20\nGL1F20\nInfrared Communication\n(IrDA1.0 Compatible)\nInfraredEmitting Diode\nFeatures\nOutline Dimensions\n(Unit: mm)\n1. IrDA1.0 compatible infrared emitting diode\n(Transmission rate : 2.4 to 115.2kbps)\n5.6\n2. Built-in infrared emitting diode circuit\n3. Recommended use in combination with detector (IS1U20)\nR 1.4\nTransparent resin\nMAX. 0.6\nDetector center\nApplications\n1. Personal computers\n1.0\n2. Portable information terminal equipment\n3. Printers\n17.9\n3-0.45\n4. Word processors\n1.27\n1.27\n=\nIrDA Abbreviation of the Infrared Data Association established\nfor standardization of infrared communication specifications\nO\n②\nⒸ\nMIN 0.3\nAbsolute Maximum Ratings\n(Ta=25°C)\nBase\nParameter\nSymbol\nRating\nUnit\nForward current\nIF\n50\nmA\nTerminal configuration\n*1 Peak forward current\nIFM\n400\nmA\n①① Base\n② Emitter\nOperating temperature\nTopr\n10 to + 70\n°C\n③ Anode\nStorage temperature\nI ste\n- 20 to +85\n°C\n88\n-\nSoldering temperature\nTsol\n260\n°C\n*1 Pulse width 78.1 μs. Duty ratio=3/16\n*2 For MAX. 3 seconds at the position of 2 mm from the resin edge\nElectro-optical Characteristics\n(Ta=25 °C)\nParameter\nSymbol\nConditions\nMIN.\nTYP.\nMAX.\nUnit\nDriving voltage\nVcc\n4.75\n5.25\nV\nHigh level input voltage\nVIII\n4.5\nVoc\nV\nVII.\n0.4\nV\nLow level input voltage\nPeak emission wavelength\nλ\nIF= 20mA\n850\n870\n900\nnm\nRadiant intensity\nJE\n40\n350\nmW/sr\nLight pulse width\ntw\n1.41\n1.6\n2.71\nμε\nVcc=5V,RL= 7.50\nVin = 4.5V\ntwin= 1.63 μs,Duty ratio: 3/16\n0 <=15°,*3\nLight rise time\ntr\n0.23\n0.6\nμε\nLight fall time\nlf\n0.17\n0.6\nμε\nInput current\nIIII\nVin = 4.5V\n1.0\n3.0\nmA\nΔλ\nIr=20mA\n40\nnm\nHalf intensity wavelength\nHalf intensity angle\n▲ 0\nIF= 20mA\n± 20\n*3 Direction of mechanical axis of the lens portion of the element: 0 =0°\nIn the absence of confirmation by device specification sheets, SHARP takes no responsibility for any defects that occur in equipment using any of SHARP\'s devices, shown in catalogs,\ndata books, etc. Contact SHARP in order to obtain the latest version of the device specification sheets before using any SHARP\'s device.\"\n"
# pages {
#   page_number: 1
#   dimension {
#     width: 1734
#     height: 2306
#     unit: "pixels"
#   }
#   layout {
#     text_anchor {
#       text_segments {
#         end_index: 2014
#       }
#     }
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 1734
#       }
#       vertices {
#         x: 1734
#         y: 2306
#       }
#       vertices {
#         y: 2306
#       }
#       normalized_vertices {
#       }
#       normalized_vertices {
#         x: 1
#       }
#       normalized_vertices {
#         x: 1
#         y: 1
#       }
#       normalized_vertices {
#         y: 1
#       }
#     }
#     orientation: PAGE_UP
#   }
#   detected_languages {
#     language_code: "en"
#     confidence: 0.870553076
#   }
#   detected_languages {
#     language_code: "und"
#     confidence: 0.123023868
#   }
#   detected_languages {
#     language_code: "lt"
#     confidence: 0.00355249806
#   }
#   detected_languages {
#     language_code: "fi"
#     confidence: 0.00287053268
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 6
#         }
#       }
#       confidence: 0.981023252
#       bounding_poly {
#         vertices {
#           x: 99
#           y: 51
#         }
#         vertices {
#           x: 280
#           y: 51
#         }
#         vertices {
#           x: 280
#           y: 76
#         }
#         vertices {
#           x: 99
#           y: 76
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.0221162178
#         }
#         normalized_vertices {
#           x: 0.161476359
#           y: 0.0221162178
#         }
#         normalized_vertices {
#           x: 0.161476359
#           y: 0.0329575
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.0329575
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 6
#           end_index: 13
#         }
#       }
#       confidence: 0.989266276
#       bounding_poly {
#         vertices {
#           x: 1539
#           y: 45
#         }
#         vertices {
#           x: 1671
#           y: 45
#         }
#         vertices {
#           x: 1671
#           y: 72
#         }
#         vertices {
#           x: 1539
#           y: 72
#         }
#         normalized_vertices {
#           x: 0.887543261
#           y: 0.0195143111
#         }
#         normalized_vertices {
#           x: 0.96366781
#           y: 0.0195143111
#         }
#         normalized_vertices {
#           x: 0.96366781
#           y: 0.0312228967
#         }
#         normalized_vertices {
#           x: 0.887543261
#           y: 0.0312228967
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 13
#           end_index: 20
#         }
#       }
#       confidence: 0.982463
#       bounding_poly {
#         vertices {
#           x: 103
#           y: 169
#         }
#         vertices {
#           x: 456
#           y: 171
#         }
#         vertices {
#           x: 456
#           y: 241
#         }
#         vertices {
#           x: 103
#           y: 239
#         }
#         normalized_vertices {
#           x: 0.0594002306
#           y: 0.0732870772
#         }
#         normalized_vertices {
#           x: 0.262975782
#           y: 0.074154377
#         }
#         normalized_vertices {
#           x: 0.262975782
#           y: 0.104509972
#         }
#         normalized_vertices {
#           x: 0.0594002306
#           y: 0.103642672
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 20
#           end_index: 87
#         }
#       }
#       confidence: 0.976025283
#       bounding_poly {
#         vertices {
#           x: 926
#           y: 159
#         }
#         vertices {
#           x: 1462
#           y: 158
#         }
#         vertices {
#           x: 1462
#           y: 302
#         }
#         vertices {
#           x: 926
#           y: 303
#         }
#         normalized_vertices {
#           x: 0.534025371
#           y: 0.0689505637
#         }
#         normalized_vertices {
#           x: 0.843137264
#           y: 0.0685169101
#         }
#         normalized_vertices {
#           x: 0.843137264
#           y: 0.1309627
#         }
#         normalized_vertices {
#           x: 0.534025371
#           y: 0.131396353
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 87
#           end_index: 96
#         }
#       }
#       confidence: 0.987338185
#       bounding_poly {
#         vertices {
#           x: 136
#           y: 365
#         }
#         vertices {
#           x: 274
#           y: 365
#         }
#         vertices {
#           x: 274
#           y: 388
#         }
#         vertices {
#           x: 136
#           y: 388
#         }
#         normalized_vertices {
#           x: 0.0784313753
#           y: 0.158282742
#         }
#         normalized_vertices {
#           x: 0.158016145
#           y: 0.158282742
#         }
#         normalized_vertices {
#           x: 0.158016145
#           y: 0.168256715
#         }
#         normalized_vertices {
#           x: 0.0784313753
#           y: 0.168256715
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 96
#           end_index: 115
#         }
#       }
#       confidence: 0.98412466
#       bounding_poly {
#         vertices {
#           x: 961
#           y: 364
#         }
#         vertices {
#           x: 1275
#           y: 364
#         }
#         vertices {
#           x: 1275
#           y: 389
#         }
#         vertices {
#           x: 961
#           y: 389
#         }
#         normalized_vertices {
#           x: 0.554209948
#           y: 0.157849088
#         }
#         normalized_vertices {
#           x: 0.735294104
#           y: 0.157849088
#         }
#         normalized_vertices {
#           x: 0.735294104
#           y: 0.168690369
#         }
#         normalized_vertices {
#           x: 0.554209948
#           y: 0.168690369
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 115
#           end_index: 126
#         }
#       }
#       confidence: 0.930035174
#       bounding_poly {
#         vertices {
#           x: 1535
#           y: 365
#         }
#         vertices {
#           x: 1671
#           y: 366
#         }
#         vertices {
#           x: 1671
#           y: 389
#         }
#         vertices {
#           x: 1535
#           y: 388
#         }
#         normalized_vertices {
#           x: 0.885236442
#           y: 0.158282742
#         }
#         normalized_vertices {
#           x: 0.96366781
#           y: 0.158716395
#         }
#         normalized_vertices {
#           x: 0.96366781
#           y: 0.168690369
#         }
#         normalized_vertices {
#           x: 0.885236442
#           y: 0.168256715
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 126
#           end_index: 211
#         }
#       }
#       confidence: 0.975460172
#       bounding_poly {
#         vertices {
#           x: 103
#           y: 412
#         }
#         vertices {
#           x: 704
#           y: 414
#         }
#         vertices {
#           x: 704
#           y: 485
#         }
#         vertices {
#           x: 103
#           y: 483
#         }
#         normalized_vertices {
#           x: 0.0594002306
#           y: 0.178664356
#         }
#         normalized_vertices {
#           x: 0.405997694
#           y: 0.179531664
#         }
#         normalized_vertices {
#           x: 0.405997694
#           y: 0.210320905
#         }
#         normalized_vertices {
#           x: 0.0594002306
#           y: 0.209453598
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 211
#           end_index: 215
#         }
#       }
#       confidence: 0.947406828
#       bounding_poly {
#         vertices {
#           x: 1198
#           y: 452
#         }
#         vertices {
#           x: 1226
#           y: 452
#         }
#         vertices {
#           x: 1226
#           y: 465
#         }
#         vertices {
#           x: 1198
#           y: 465
#         }
#         normalized_vertices {
#           x: 0.690888107
#           y: 0.196010411
#         }
#         normalized_vertices {
#           x: 0.70703578
#           y: 0.196010411
#         }
#         normalized_vertices {
#           x: 0.70703578
#           y: 0.201647878
#         }
#         normalized_vertices {
#           x: 0.690888107
#           y: 0.201647878
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 215
#           end_index: 316
#         }
#       }
#       confidence: 0.979507506
#       bounding_poly {
#         vertices {
#           x: 99
#           y: 506
#         }
#         vertices {
#           x: 792
#           y: 506
#         }
#         vertices {
#           x: 792
#           y: 579
#         }
#         vertices {
#           x: 99
#           y: 579
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.219427586
#         }
#         normalized_vertices {
#           x: 0.456747413
#           y: 0.219427586
#         }
#         normalized_vertices {
#           x: 0.456747413
#           y: 0.251084119
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.251084119
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 316
#           end_index: 322
#         }
#       }
#       confidence: 0.921845436
#       bounding_poly {
#         vertices {
#           x: 1140
#           y: 589
#         }
#         vertices {
#           x: 1188
#           y: 590
#         }
#         vertices {
#           x: 1188
#           y: 604
#         }
#         vertices {
#           x: 1140
#           y: 603
#         }
#         normalized_vertices {
#           x: 0.65743947
#           y: 0.255420655
#         }
#         normalized_vertices {
#           x: 0.685121119
#           y: 0.255854279
#         }
#         normalized_vertices {
#           x: 0.685121119
#           y: 0.261925399
#         }
#         normalized_vertices {
#           x: 0.65743947
#           y: 0.261491776
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 322
#           end_index: 340
#         }
#       }
#       confidence: 0.988437653
#       bounding_poly {
#         vertices {
#           x: 1448
#           y: 589
#         }
#         vertices {
#           x: 1628
#           y: 588
#         }
#         vertices {
#           x: 1628
#           y: 609
#         }
#         vertices {
#           x: 1448
#           y: 610
#         }
#         normalized_vertices {
#           x: 0.835063457
#           y: 0.255420655
#         }
#         normalized_vertices {
#           x: 0.938869655
#           y: 0.254987
#         }
#         normalized_vertices {
#           x: 0.938869655
#           y: 0.264093667
#         }
#         normalized_vertices {
#           x: 0.835063457
#           y: 0.264527321
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 340
#           end_index: 349
#         }
#       }
#       confidence: 0.968699634
#       bounding_poly {
#         vertices {
#           x: 1014
#           y: 640
#         }
#         vertices {
#           x: 1120
#           y: 641
#         }
#         vertices {
#           x: 1120
#           y: 659
#         }
#         vertices {
#           x: 1014
#           y: 658
#         }
#         normalized_vertices {
#           x: 0.58477509
#           y: 0.277536869
#         }
#         normalized_vertices {
#           x: 0.645905435
#           y: 0.277970523
#         }
#         normalized_vertices {
#           x: 0.645905435
#           y: 0.285776228
#         }
#         normalized_vertices {
#           x: 0.58477509
#           y: 0.285342574
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 349
#           end_index: 365
#         }
#       }
#       confidence: 0.988429368
#       bounding_poly {
#         vertices {
#           x: 971
#           y: 735
#         }
#         vertices {
#           x: 1132
#           y: 736
#         }
#         vertices {
#           x: 1132
#           y: 753
#         }
#         vertices {
#           x: 971
#           y: 752
#         }
#         normalized_vertices {
#           x: 0.559976935
#           y: 0.318733752
#         }
#         normalized_vertices {
#           x: 0.652825832
#           y: 0.319167376
#         }
#         normalized_vertices {
#           x: 0.652825832
#           y: 0.326539457
#         }
#         normalized_vertices {
#           x: 0.559976935
#           y: 0.326105803
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 365
#           end_index: 378
#         }
#       }
#       confidence: 0.984732151
#       bounding_poly {
#         vertices {
#           x: 135
#           y: 775
#         }
#         vertices {
#           x: 335
#           y: 775
#         }
#         vertices {
#           x: 335
#           y: 804
#         }
#         vertices {
#           x: 135
#           y: 804
#         }
#         normalized_vertices {
#           x: 0.0778546706
#           y: 0.336079806
#         }
#         normalized_vertices {
#           x: 0.193194926
#           y: 0.336079806
#         }
#         normalized_vertices {
#           x: 0.193194926
#           y: 0.348655671
#         }
#         normalized_vertices {
#           x: 0.0778546706
#           y: 0.348655671
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 378
#           end_index: 400
#         }
#       }
#       confidence: 0.985144198
#       bounding_poly {
#         vertices {
#           x: 103
#           y: 821
#         }
#         vertices {
#           x: 376
#           y: 827
#         }
#         vertices {
#           x: 375
#           y: 854
#         }
#         vertices {
#           x: 102
#           y: 848
#         }
#         normalized_vertices {
#           x: 0.0594002306
#           y: 0.356027752
#         }
#         normalized_vertices {
#           x: 0.216839671
#           y: 0.358629674
#         }
#         normalized_vertices {
#           x: 0.216262981
#           y: 0.370338261
#         }
#         normalized_vertices {
#           x: 0.0588235296
#           y: 0.36773634
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 400
#           end_index: 404
#         }
#       }
#       confidence: 0.974674821
#       bounding_poly {
#         vertices {
#           x: 1258
#           y: 840
#         }
#         vertices {
#           x: 1258
#           y: 817
#         }
#         vertices {
#           x: 1271
#           y: 817
#         }
#         vertices {
#           x: 1271
#           y: 840
#         }
#         normalized_vertices {
#           x: 0.725490212
#           y: 0.364267141
#         }
#         normalized_vertices {
#           x: 0.725490212
#           y: 0.354293138
#         }
#         normalized_vertices {
#           x: 0.732987285
#           y: 0.354293138
#         }
#         normalized_vertices {
#           x: 0.732987285
#           y: 0.364267141
#         }
#       }
#       orientation: PAGE_LEFT
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 404
#           end_index: 447
#         }
#       }
#       confidence: 0.987523258
#       bounding_poly {
#         vertices {
#           x: 99
#           y: 866
#         }
#         vertices {
#           x: 641
#           y: 869
#         }
#         vertices {
#           x: 641
#           y: 898
#         }
#         vertices {
#           x: 99
#           y: 895
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.375542074
#         }
#         normalized_vertices {
#           x: 0.369665504
#           y: 0.376843
#         }
#         normalized_vertices {
#           x: 0.369665504
#           y: 0.3894189
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.388117939
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 447
#           end_index: 459
#         }
#       }
#       confidence: 0.985984504
#       bounding_poly {
#         vertices {
#           x: 102
#           y: 917
#         }
#         vertices {
#           x: 228
#           y: 917
#         }
#         vertices {
#           x: 228
#           y: 939
#         }
#         vertices {
#           x: 102
#           y: 939
#         }
#         normalized_vertices {
#           x: 0.0588235296
#           y: 0.397658288
#         }
#         normalized_vertices {
#           x: 0.131487891
#           y: 0.397658288
#         }
#         normalized_vertices {
#           x: 0.131487891
#           y: 0.407198608
#         }
#         normalized_vertices {
#           x: 0.0588235296
#           y: 0.407198608
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 459
#           end_index: 464
#         }
#       }
#       confidence: 0.988385379
#       bounding_poly {
#         vertices {
#           x: 1298
#           y: 950
#         }
#         vertices {
#           x: 1298
#           y: 913
#         }
#         vertices {
#           x: 1311
#           y: 913
#         }
#         vertices {
#           x: 1311
#           y: 950
#         }
#         normalized_vertices {
#           x: 0.748558223
#           y: 0.411968768
#         }
#         normalized_vertices {
#           x: 0.748558223
#           y: 0.395923674
#         }
#         normalized_vertices {
#           x: 0.756055355
#           y: 0.395923674
#         }
#         normalized_vertices {
#           x: 0.756055355
#           y: 0.411968768
#         }
#       }
#       orientation: PAGE_LEFT
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 464
#           end_index: 471
#         }
#       }
#       confidence: 0.977346778
#       bounding_poly {
#         vertices {
#           x: 1096
#           y: 932
#         }
#         vertices {
#           x: 1154
#           y: 932
#         }
#         vertices {
#           x: 1154
#           y: 946
#         }
#         vertices {
#           x: 1096
#           y: 946
#         }
#         normalized_vertices {
#           x: 0.632064581
#           y: 0.404163063
#         }
#         normalized_vertices {
#           x: 0.665513277
#           y: 0.404163063
#         }
#         normalized_vertices {
#           x: 0.665513277
#           y: 0.410234183
#         }
#         normalized_vertices {
#           x: 0.632064581
#           y: 0.410234183
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 471
#           end_index: 490
#         }
#       }
#       confidence: 0.985235691
#       bounding_poly {
#         vertices {
#           x: 99
#           y: 960
#         }
#         vertices {
#           x: 342
#           y: 969
#         }
#         vertices {
#           x: 341
#           y: 995
#         }
#         vertices {
#           x: 98
#           y: 986
#         }
#         normalized_vertices {
#           x: 0.0570934266
#           y: 0.416305304
#         }
#         normalized_vertices {
#           x: 0.197231829
#           y: 0.420208156
#         }
#         normalized_vertices {
#           x: 0.196655139
#           y: 0.43148309
#         }
#         normalized_vertices {
#           x: 0.0565167256
#           y: 0.427580237
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 490
#           end_index: 495
#         }
#       }
#       confidence: 0.977177501
#       bounding_poly {
#         vertices {
#           x: 1125
#           y: 1001
#         }
#         vertices {
#           x: 1162
#           y: 1001
#         }
#         vertices {
#           x: 1162
#           y: 1015
#         }
#         vertices {
#           x: 1125
#           y: 1015
#         }
#         normalized_vertices {
#           x: 0.648788929
#           y: 0.434084982
#         }
#         normalized_vertices {
#           x: 0.670126855
#           y: 0.434084982
#         }
#         normalized_vertices {
#           x: 0.670126855
#           y: 0.440156102
#         }
#         normalized_vertices {
#           x: 0.648788929
#           y: 0.440156102
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 495
#           end_index: 500
#         }
#       }
#       confidence: 0.985066235
#       bounding_poly {
#         vertices {
#           x: 1254
#           y: 1000
#         }
#         vertices {
#           x: 1293
#           y: 1001
#         }
#         vertices {
#           x: 1293
#           y: 1017
#         }
#         vertices {
#           x: 1254
#           y: 1016
#         }
#         normalized_vertices {
#           x: 0.723183393
#           y: 0.433651358
#         }
#         normalized_vertices {
#           x: 0.745674729
#           y: 0.434084982
#         }
#         normalized_vertices {
#           x: 0.745674729
#           y: 0.441023409
#         }
#         normalized_vertices {
#           x: 0.723183393
#           y: 0.440589756
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 500
#           end_index: 502
#         }
#       }
#       confidence: 0.700175762
#       bounding_poly {
#         vertices {
#           x: 1172
#           y: 1025
#         }
#         vertices {
#           x: 1184
#           y: 1025
#         }
#         vertices {
#           x: 1185
#           y: 1057
#         }
#         vertices {
#           x: 1173
#           y: 1057
#         }
#         normalized_vertices {
#           x: 0.675893903
#           y: 0.444492638
#         }
#         normalized_vertices {
#           x: 0.6828143
#           y: 0.444492638
#         }
#         normalized_vertices {
#           x: 0.683391
#           y: 0.458369464
#         }
#         normalized_vertices {
#           x: 0.676470578
#           y: 0.458369464
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 502
#           end_index: 626
#         }
#       }
#       confidence: 0.987103343
#       bounding_poly {
#         vertices {
#           x: 100
#           y: 1032
#         }
#         vertices {
#           x: 826
#           y: 1034
#         }
#         vertices {
#           x: 826
#           y: 1099
#         }
#         vertices {
#           x: 100
#           y: 1097
#         }
#         normalized_vertices {
#           x: 0.0576701276
#           y: 0.447528183
#         }
#         normalized_vertices {
#           x: 0.476355255
#           y: 0.448395491
#         }
#         normalized_vertices {
#           x: 0.476355255
#           y: 0.476582825
#         }
#         normalized_vertices {
#           x: 0.0576701276
#           y: 0.475715518
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 626
#           end_index: 632
#         }
#       }
#       confidence: 0.439931422
#       bounding_poly {
#         vertices {
#           x: 1245
#           y: 1090
#         }
#         vertices {
#           x: 1244
#           y: 1118
#         }
#         vertices {
#           x: 1160
#           y: 1116
#         }
#         vertices {
#           x: 1161
#           y: 1088
#         }
#         normalized_vertices {
#           x: 0.717993081
#           y: 0.472679973
#         }
#         normalized_vertices {
#           x: 0.717416406
#           y: 0.484822214
#         }
#         normalized_vertices {
#           x: 0.668973446
#           y: 0.483954906
#         }
#         normalized_vertices {
#           x: 0.66955018
#           y: 0.471812665
#         }
#       }
#       orientation: PAGE_RIGHT
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 632
#           end_index: 640
#         }
#       }
#       confidence: 0.963276327
#       bounding_poly {
#         vertices {
#           x: 1299
#           y: 1161
#         }
#         vertices {
#           x: 1299
#           y: 1090
#         }
#         vertices {
#           x: 1316
#           y: 1090
#         }
#         vertices {
#           x: 1316
#           y: 1161
#         }
#         normalized_vertices {
#           x: 0.749134958
#           y: 0.503469229
#         }
#         normalized_vertices {
#           x: 0.749134958
#           y: 0.472679973
#         }
#         normalized_vertices {
#           x: 0.758938849
#           y: 0.472679973
#         }
#         normalized_vertices {
#           x: 0.758938849
#           y: 0.503469229
#         }
#       }
#       orientation: PAGE_LEFT
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 640
#           end_index: 665
#         }
#       }
#       confidence: 0.985045373
#       bounding_poly {
#         vertices {
#           x: 136
#           y: 1190
#         }
#         vertices {
#           x: 576
#           y: 1194
#         }
#         vertices {
#           x: 576
#           y: 1225
#         }
#         vertices {
#           x: 136
#           y: 1221
#         }
#         normalized_vertices {
#           x: 0.0784313753
#           y: 0.516045094
#         }
#         normalized_vertices {
#           x: 0.332179934
#           y: 0.517779708
#         }
#         normalized_vertices {
#           x: 0.332179934
#           y: 0.53122288
#         }
#         normalized_vertices {
#           x: 0.0784313753
#           y: 0.529488266
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 665
#           end_index: 675
#         }
#       }
#       confidence: 0.925394416
#       bounding_poly {
#         vertices {
#           x: 785
#           y: 1197
#         }
#         vertices {
#           x: 906
#           y: 1195
#         }
#         vertices {
#           x: 906
#           y: 1219
#         }
#         vertices {
#           x: 785
#           y: 1221
#         }
#         normalized_vertices {
#           x: 0.452710509
#           y: 0.519080639
#         }
#         normalized_vertices {
#           x: 0.522491336
#           y: 0.518213332
#         }
#         normalized_vertices {
#           x: 0.522491336
#           y: 0.528621
#         }
#         normalized_vertices {
#           x: 0.452710509
#           y: 0.529488266
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 675
#           end_index: 680
#         }
#       }
#       confidence: 0.977317333
#       bounding_poly {
#         vertices {
#           x: 1358
#           y: 1193
#         }
#         vertices {
#           x: 1410
#           y: 1194
#         }
#         vertices {
#           x: 1410
#           y: 1211
#         }
#         vertices {
#           x: 1358
#           y: 1210
#         }
#         normalized_vertices {
#           x: 0.783160329
#           y: 0.517346
#         }
#         normalized_vertices {
#           x: 0.813148797
#           y: 0.517779708
#         }
#         normalized_vertices {
#           x: 0.813148797
#           y: 0.525151789
#         }
#         normalized_vertices {
#           x: 0.783160329
#           y: 0.524718106
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 680
#           end_index: 690
#         }
#       }
#       confidence: 0.988157928
#       bounding_poly {
#         vertices {
#           x: 257
#           y: 1252
#         }
#         vertices {
#           x: 373
#           y: 1253
#         }
#         vertices {
#           x: 373
#           y: 1272
#         }
#         vertices {
#           x: 257
#           y: 1271
#         }
#         normalized_vertices {
#           x: 0.148212224
#           y: 0.542931497
#         }
#         normalized_vertices {
#           x: 0.215109572
#           y: 0.543365121
#         }
#         normalized_vertices {
#           x: 0.215109572
#           y: 0.551604509
#         }
#         normalized_vertices {
#           x: 0.148212224
#           y: 0.551170886
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 690
#           end_index: 697
#         }
#       }
#       confidence: 0.977619648
#       bounding_poly {
#         vertices {
#           x: 508
#           y: 1251
#         }
#         vertices {
#           x: 597
#           y: 1252
#         }
#         vertices {
#           x: 597
#           y: 1277
#         }
#         vertices {
#           x: 508
#           y: 1276
#         }
#         normalized_vertices {
#           x: 0.29296425
#           y: 0.542497814
#         }
#         normalized_vertices {
#           x: 0.344290644
#           y: 0.542931497
#         }
#         normalized_vertices {
#           x: 0.344290644
#           y: 0.553772748
#         }
#         normalized_vertices {
#           x: 0.29296425
#           y: 0.553339124
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 697
#           end_index: 704
#         }
#       }
#       confidence: 0.981678
#       bounding_poly {
#         vertices {
#           x: 668
#           y: 1251
#         }
#         vertices {
#           x: 742
#           y: 1250
#         }
#         vertices {
#           x: 742
#           y: 1276
#         }
#         vertices {
#           x: 668
#           y: 1277
#         }
#         normalized_vertices {
#           x: 0.385236442
#           y: 0.542497814
#         }
#         normalized_vertices {
#           x: 0.427912354
#           y: 0.54206419
#         }
#         normalized_vertices {
#           x: 0.427912354
#           y: 0.553339124
#         }
#         normalized_vertices {
#           x: 0.385236442
#           y: 0.553772748
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 704
#           end_index: 709
#         }
#       }
#       confidence: 0.983926475
#       bounding_poly {
#         vertices {
#           x: 815
#           y: 1252
#         }
#         vertices {
#           x: 866
#           y: 1252
#         }
#         vertices {
#           x: 866
#           y: 1270
#         }
#         vertices {
#           x: 815
#           y: 1270
#         }
#         normalized_vertices {
#           x: 0.470011532
#           y: 0.542931497
#         }
#         normalized_vertices {
#           x: 0.499423295
#           y: 0.542931497
#         }
#         normalized_vertices {
#           x: 0.499423295
#           y: 0.550737202
#         }
#         normalized_vertices {
#           x: 0.470011532
#           y: 0.550737202
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 709
#           end_index: 725
#         }
#       }
#       confidence: 0.986260712
#       bounding_poly {
#         vertices {
#           x: 133
#           y: 1293
#         }
#         vertices {
#           x: 317
#           y: 1295
#         }
#         vertices {
#           x: 317
#           y: 1315
#         }
#         vertices {
#           x: 133
#           y: 1313
#         }
#         normalized_vertices {
#           x: 0.0767012686
#           y: 0.560711205
#         }
#         normalized_vertices {
#           x: 0.1828143
#           y: 0.561578512
#         }
#         normalized_vertices {
#           x: 0.1828143
#           y: 0.570251524
#         }
#         normalized_vertices {
#           x: 0.0767012686
#           y: 0.569384217
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 725
#           end_index: 728
#         }
#       }
#       confidence: 0.732800245
#       bounding_poly {
#         vertices {
#           x: 542
#           y: 1295
#         }
#         vertices {
#           x: 561
#           y: 1295
#         }
#         vertices {
#           x: 561
#           y: 1313
#         }
#         vertices {
#           x: 542
#           y: 1313
#         }
#         normalized_vertices {
#           x: 0.312572092
#           y: 0.561578512
#         }
#         normalized_vertices {
#           x: 0.323529422
#           y: 0.561578512
#         }
#         normalized_vertices {
#           x: 0.323529422
#           y: 0.569384217
#         }
#         normalized_vertices {
#           x: 0.312572092
#           y: 0.569384217
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 728
#           end_index: 731
#         }
#       }
#       confidence: 0.985410333
#       bounding_poly {
#         vertices {
#           x: 688
#           y: 1294
#         }
#         vertices {
#           x: 718
#           y: 1294
#         }
#         vertices {
#           x: 718
#           y: 1312
#         }
#         vertices {
#           x: 688
#           y: 1312
#         }
#         normalized_vertices {
#           x: 0.396770477
#           y: 0.561144829
#         }
#         normalized_vertices {
#           x: 0.4140715
#           y: 0.561144829
#         }
#         normalized_vertices {
#           x: 0.4140715
#           y: 0.568950593
#         }
#         normalized_vertices {
#           x: 0.396770477
#           y: 0.568950593
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 731
#           end_index: 734
#         }
#       }
#       confidence: 0.861233115
#       bounding_poly {
#         vertices {
#           x: 822
#           y: 1295
#         }
#         vertices {
#           x: 866
#           y: 1295
#         }
#         vertices {
#           x: 866
#           y: 1312
#         }
#         vertices {
#           x: 822
#           y: 1312
#         }
#         normalized_vertices {
#           x: 0.474048436
#           y: 0.561578512
#         }
#         normalized_vertices {
#           x: 0.499423295
#           y: 0.561578512
#         }
#         normalized_vertices {
#           x: 0.499423295
#           y: 0.568950593
#         }
#         normalized_vertices {
#           x: 0.474048436
#           y: 0.568950593
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 734
#           end_index: 757
#         }
#       }
#       confidence: 0.987887144
#       bounding_poly {
#         vertices {
#           x: 1113
#           y: 1294
#         }
#         vertices {
#           x: 1316
#           y: 1298
#         }
#         vertices {
#           x: 1316
#           y: 1318
#         }
#         vertices {
#           x: 1113
#           y: 1314
#         }
#         normalized_vertices {
#           x: 0.641868532
#           y: 0.561144829
#         }
#         normalized_vertices {
#           x: 0.758938849
#           y: 0.562879443
#         }
#         normalized_vertices {
#           x: 0.758938849
#           y: 0.571552455
#         }
#         normalized_vertices {
#           x: 0.641868532
#           y: 0.569817841
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 757
#           end_index: 781
#         }
#       }
#       confidence: 0.946177959
#       bounding_poly {
#         vertices {
#           x: 112
#           y: 1332
#         }
#         vertices {
#           x: 375
#           y: 1335
#         }
#         vertices {
#           x: 375
#           y: 1358
#         }
#         vertices {
#           x: 112
#           y: 1355
#         }
#         normalized_vertices {
#           x: 0.0645905435
#           y: 0.577623606
#         }
#         normalized_vertices {
#           x: 0.216262981
#           y: 0.578924537
#         }
#         normalized_vertices {
#           x: 0.216262981
#           y: 0.58889854
#         }
#         normalized_vertices {
#           x: 0.0645905435
#           y: 0.587597549
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 781
#           end_index: 785
#         }
#       }
#       confidence: 0.955868959
#       bounding_poly {
#         vertices {
#           x: 538
#           y: 1337
#         }
#         vertices {
#           x: 574
#           y: 1338
#         }
#         vertices {
#           x: 574
#           y: 1357
#         }
#         vertices {
#           x: 538
#           y: 1356
#         }
#         normalized_vertices {
#           x: 0.310265273
#           y: 0.579791844
#         }
#         normalized_vertices {
#           x: 0.331026524
#           y: 0.580225527
#         }
#         normalized_vertices {
#           x: 0.331026524
#           y: 0.588464856
#         }
#         normalized_vertices {
#           x: 0.310265273
#           y: 0.588031232
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 785
#           end_index: 789
#         }
#       }
#       confidence: 0.990620255
#       bounding_poly {
#         vertices {
#           x: 680
#           y: 1337
#         }
#         vertices {
#           x: 723
#           y: 1337
#         }
#         vertices {
#           x: 723
#           y: 1354
#         }
#         vertices {
#           x: 680
#           y: 1354
#         }
#         normalized_vertices {
#           x: 0.392156869
#           y: 0.579791844
#         }
#         normalized_vertices {
#           x: 0.416955024
#           y: 0.579791844
#         }
#         normalized_vertices {
#           x: 0.416955024
#           y: 0.587163925
#         }
#         normalized_vertices {
#           x: 0.392156869
#           y: 0.587163925
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 789
#           end_index: 792
#         }
#       }
#       confidence: 0.844752431
#       bounding_poly {
#         vertices {
#           x: 821
#           y: 1337
#         }
#         vertices {
#           x: 864
#           y: 1337
#         }
#         vertices {
#           x: 864
#           y: 1355
#         }
#         vertices {
#           x: 821
#           y: 1355
#         }
#         normalized_vertices {
#           x: 0.473471731
#           y: 0.579791844
#         }
#         normalized_vertices {
#           x: 0.498269886
#           y: 0.579791844
#         }
#         normalized_vertices {
#           x: 0.498269886
#           y: 0.587597549
#         }
#         normalized_vertices {
#           x: 0.473471731
#           y: 0.587597549
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 792
#           end_index: 800
#         }
#       }
#       confidence: 0.820479691
#       bounding_poly {
#         vertices {
#           x: 1128
#           y: 1329
#         }
#         vertices {
#           x: 1211
#           y: 1329
#         }
#         vertices {
#           x: 1211
#           y: 1349
#         }
#         vertices {
#           x: 1128
#           y: 1349
#         }
#         normalized_vertices {
#           x: 0.650519
#           y: 0.576322615
#         }
#         normalized_vertices {
#           x: 0.698385239
#           y: 0.576322615
#         }
#         normalized_vertices {
#           x: 0.698385239
#           y: 0.584995687
#         }
#         normalized_vertices {
#           x: 0.650519
#           y: 0.584995687
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 800
#           end_index: 810
#         }
#       }
#       confidence: 0.915151715
#       bounding_poly {
#         vertices {
#           x: 1128
#           y: 1364
#         }
#         vertices {
#           x: 1229
#           y: 1362
#         }
#         vertices {
#           x: 1229
#           y: 1379
#         }
#         vertices {
#           x: 1128
#           y: 1381
#         }
#         normalized_vertices {
#           x: 0.650519
#           y: 0.591500461
#         }
#         normalized_vertices {
#           x: 0.708765864
#           y: 0.590633154
#         }
#         normalized_vertices {
#           x: 0.708765864
#           y: 0.598005176
#         }
#         normalized_vertices {
#           x: 0.650519
#           y: 0.598872483
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 810
#           end_index: 832
#         }
#       }
#       confidence: 0.982767582
#       bounding_poly {
#         vertices {
#           x: 133
#           y: 1377
#         }
#         vertices {
#           x: 390
#           y: 1380
#         }
#         vertices {
#           x: 390
#           y: 1405
#         }
#         vertices {
#           x: 133
#           y: 1402
#         }
#         normalized_vertices {
#           x: 0.0767012686
#           y: 0.597137928
#         }
#         normalized_vertices {
#           x: 0.224913493
#           y: 0.598438859
#         }
#         normalized_vertices {
#           x: 0.224913493
#           y: 0.609280109
#         }
#         normalized_vertices {
#           x: 0.0767012686
#           y: 0.607979178
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 832
#           end_index: 837
#         }
#       }
#       confidence: 0.91502738
#       bounding_poly {
#         vertices {
#           x: 537
#           y: 1377
#         }
#         vertices {
#           x: 583
#           y: 1379
#         }
#         vertices {
#           x: 582
#           y: 1402
#         }
#         vertices {
#           x: 536
#           y: 1400
#         }
#         normalized_vertices {
#           x: 0.309688568
#           y: 0.597137928
#         }
#         normalized_vertices {
#           x: 0.336216837
#           y: 0.598005176
#         }
#         normalized_vertices {
#           x: 0.335640132
#           y: 0.607979178
#         }
#         normalized_vertices {
#           x: 0.309111893
#           y: 0.607111871
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 837
#           end_index: 848
#         }
#       }
#       confidence: 0.862748265
#       bounding_poly {
#         vertices {
#           x: 664
#           y: 1378
#         }
#         vertices {
#           x: 765
#           y: 1377
#         }
#         vertices {
#           x: 765
#           y: 1398
#         }
#         vertices {
#           x: 664
#           y: 1399
#         }
#         normalized_vertices {
#           x: 0.382929653
#           y: 0.597571552
#         }
#         normalized_vertices {
#           x: 0.441176474
#           y: 0.597137928
#         }
#         normalized_vertices {
#           x: 0.441176474
#           y: 0.606244564
#         }
#         normalized_vertices {
#           x: 0.382929653
#           y: 0.606678247
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 848
#           end_index: 851
#         }
#       }
#       confidence: 0.7742697
#       bounding_poly {
#         vertices {
#           x: 829
#           y: 1376
#         }
#         vertices {
#           x: 855
#           y: 1376
#         }
#         vertices {
#           x: 855
#           y: 1397
#         }
#         vertices {
#           x: 829
#           y: 1397
#         }
#         normalized_vertices {
#           x: 0.478085339
#           y: 0.596704245
#         }
#         normalized_vertices {
#           x: 0.493079573
#           y: 0.596704245
#         }
#         normalized_vertices {
#           x: 0.493079573
#           y: 0.60581094
#         }
#         normalized_vertices {
#           x: 0.478085339
#           y: 0.60581094
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 851
#           end_index: 859
#         }
#       }
#       confidence: 0.906301558
#       bounding_poly {
#         vertices {
#           x: 1129
#           y: 1396
#         }
#         vertices {
#           x: 1222
#           y: 1395
#         }
#         vertices {
#           x: 1222
#           y: 1411
#         }
#         vertices {
#           x: 1129
#           y: 1412
#         }
#         normalized_vertices {
#           x: 0.651095748
#           y: 0.605377257
#         }
#         normalized_vertices {
#           x: 0.704728961
#           y: 0.604943633
#         }
#         normalized_vertices {
#           x: 0.704728961
#           y: 0.611882031
#         }
#         normalized_vertices {
#           x: 0.651095748
#           y: 0.612315714
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 859
#           end_index: 879
#         }
#       }
#       confidence: 0.989091277
#       bounding_poly {
#         vertices {
#           x: 133
#           y: 1418
#         }
#         vertices {
#           x: 364
#           y: 1421
#         }
#         vertices {
#           x: 364
#           y: 1446
#         }
#         vertices {
#           x: 133
#           y: 1443
#         }
#         normalized_vertices {
#           x: 0.0767012686
#           y: 0.614917636
#         }
#         normalized_vertices {
#           x: 0.209919259
#           y: 0.616218567
#         }
#         normalized_vertices {
#           x: 0.209919259
#           y: 0.627059817
#         }
#         normalized_vertices {
#           x: 0.0767012686
#           y: 0.625758886
#         }
#       }
#       orientation: PAGE_UP
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 879
#           end_index: 885
#         }
#       }
#       confidence: 0.543122351
#       bounding_poly {
#         vertices {
#           x: 541
#           y: 1415
#         }
#         vertices {
#           x: 582
#           y: 1426
#         }
#         vertices {
#           x: 577
#           y: 1448
#         }
#         vertices {
#           x: 535
#           y: 1436
#         }
#         normalized_vertices {
#           x: 0.311995387
#           y: 0.613616645
#         }
#         normalized_vertices {
#           x: 0.335640132
#           y: 0.618386805
#         }
#         normalized_vertices {
#           x: 0.332756639
#           y: 0.627927125
# ...
#           normalized_vertices {
#             x: 0.836216867
#             y: 0.805724204
#           }
#           normalized_vertices {
#             x: 0.810842
#             y: 0.805724204
#           }
#         }
#       }
#     }
#     id: "24"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1315
#         end_index: 1317
#       }
#     }
#     type_: "quantity"
#     mention_text: "40"
#     confidence: 0.98705554
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.682237625
#             y: 0.815698206
#           }
#           normalized_vertices {
#             x: 0.698385239
#             y: 0.815698206
#           }
#           normalized_vertices {
#             x: 0.698385239
#             y: 0.823070228
#           }
#           normalized_vertices {
#             x: 0.682237625
#             y: 0.823070228
#           }
#         }
#       }
#     }
#     id: "25"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1318
#         end_index: 1321
#       }
#     }
#     type_: "quantity"
#     mention_text: "350"
#     confidence: 0.892720044
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.812572062
#             y: 0.815264523
#           }
#           normalized_vertices {
#             x: 0.838523626
#             y: 0.815264523
#           }
#           normalized_vertices {
#             x: 0.838523626
#             y: 0.823503911
#           }
#           normalized_vertices {
#             x: 0.812572062
#             y: 0.823503911
#           }
#         }
#       }
#     }
#     id: "26"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1349
#         end_index: 1353
#       }
#     }
#     type_: "quantity"
#     mention_text: "1.41"
#     confidence: 0.951689363
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.677624
#             y: 0.833477855
#           }
#           normalized_vertices {
#             x: 0.702998817
#             y: 0.833477855
#           }
#           normalized_vertices {
#             x: 0.702998817
#             y: 0.841283619
#           }
#           normalized_vertices {
#             x: 0.677624
#             y: 0.841283619
#           }
#         }
#       }
#     }
#     id: "27"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1354
#         end_index: 1357
#       }
#     }
#     type_: "quantity"
#     mention_text: "1.6"
#     confidence: 0.883057773
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.747404873
#             y: 0.833477855
#           }
#           normalized_vertices {
#             x: 0.766436
#             y: 0.833477855
#           }
#           normalized_vertices {
#             x: 0.766436
#             y: 0.841283619
#           }
#           normalized_vertices {
#             x: 0.747404873
#             y: 0.841283619
#           }
#         }
#       }
#     }
#     id: "28"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1358
#         end_index: 1362
#       }
#     }
#     type_: "quantity"
#     mention_text: "2.71"
#     confidence: 0.670155585
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.809111893
#             y: 0.833044231
#           }
#           normalized_vertices {
#             x: 0.835063457
#             y: 0.833044231
#           }
#           normalized_vertices {
#             x: 0.835063457
#             y: 0.841283619
#           }
#           normalized_vertices {
#             x: 0.809111893
#             y: 0.841283619
#           }
#         }
#       }
#     }
#     id: "29"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1377
#         end_index: 1381
#       }
#     }
#     type_: "price"
#     mention_text: "7.50"
#     confidence: 0.394468516
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.533448696
#             y: 0.818300068
#           }
#           normalized_vertices {
#             x: 0.565167248
#             y: 0.818300068
#           }
#           normalized_vertices {
#             x: 0.565167248
#             y: 0.827840388
#           }
#           normalized_vertices {
#             x: 0.533448696
#             y: 0.827840388
#           }
#         }
#       }
#     }
#     id: "30"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1388
#         end_index: 1392
#       }
#     }
#     type_: "quantity"
#     mention_text: "4.5V"
#     confidence: 0.888470292
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.468858123
#             y: 0.833911538
#           }
#           normalized_vertices {
#             x: 0.501153409
#             y: 0.833911538
#           }
#           normalized_vertices {
#             x: 0.501153409
#             y: 0.84258455
#           }
#           normalized_vertices {
#             x: 0.468858123
#             y: 0.84258455
#           }
#         }
#       }
#     }
#     id: "31"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1399
#         end_index: 1406
#       }
#     }
#     type_: "quantity"
#     mention_text: "1.63 μs"
#     confidence: 0.910167933
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.469434828
#             y: 0.848222
#           }
#           normalized_vertices {
#             x: 0.516147614
#             y: 0.848222
#           }
#           normalized_vertices {
#             x: 0.516147614
#             y: 0.859063327
#           }
#           normalized_vertices {
#             x: 0.469434828
#             y: 0.859063327
#           }
#         }
#       }
#     }
#     id: "32"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1419
#         end_index: 1423
#       }
#     }
#     type_: "date_time"
#     mention_text: "3/16"
#     confidence: 0.936873138
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.600346
#             y: 0.846921086
#           }
#           normalized_vertices {
#             x: 0.629181087
#             y: 0.846921086
#           }
#           normalized_vertices {
#             x: 0.629181087
#             y: 0.857762337
#           }
#           normalized_vertices {
#             x: 0.600346
#             y: 0.857762337
#           }
#         }
#       }
#     }
#     id: "33"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1424
#         end_index: 1425
#       }
#     }
#     type_: "quantity"
#     mention_text: "0"
#     confidence: 0.561215699
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.433102667
#             y: 0.863833487
#           }
#           normalized_vertices {
#             x: 0.442329884
#             y: 0.863833487
#           }
#           normalized_vertices {
#             x: 0.442329884
#             y: 0.872506499
#           }
#           normalized_vertices {
#             x: 0.433102667
#             y: 0.872506499
#           }
#         }
#       }
#     }
#     id: "34"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1454
#         end_index: 1458
#       }
#     }
#     type_: "quantity"
#     mention_text: "0.23"
#     confidence: 0.803216
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.742214561
#             y: 0.850390315
#           }
#           normalized_vertices {
#             x: 0.770472884
#             y: 0.850390315
#           }
#           normalized_vertices {
#             x: 0.770472884
#             y: 0.859496951
#           }
#           normalized_vertices {
#             x: 0.742214561
#             y: 0.859496951
#           }
#         }
#       }
#     }
#     id: "35"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1459
#         end_index: 1462
#       }
#     }
#     type_: "quantity"
#     mention_text: "0.6"
#     confidence: 0.565770209
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.813725471
#             y: 0.851257563
#           }
#           normalized_vertices {
#             x: 0.835063457
#             y: 0.851257563
#           }
#           normalized_vertices {
#             x: 0.835063457
#             y: 0.859063327
#           }
#           normalized_vertices {
#             x: 0.813725471
#             y: 0.859063327
#           }
#         }
#       }
#     }
#     id: "36"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1485
#         end_index: 1489
#       }
#     }
#     type_: "quantity"
#     mention_text: "0.17"
#     confidence: 0.781143785
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.742791235
#             y: 0.869037271
#           }
#           normalized_vertices {
#             x: 0.770472884
#             y: 0.869037271
#           }
#           normalized_vertices {
#             x: 0.770472884
#             y: 0.877710342
#           }
#           normalized_vertices {
#             x: 0.742791235
#             y: 0.877710342
#           }
#         }
#       }
#     }
#     id: "37"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1490
#         end_index: 1493
#       }
#     }
#     type_: "quantity"
#     mention_text: "0.6"
#     confidence: 0.63160032
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.813148797
#             y: 0.869037271
#           }
#           normalized_vertices {
#             x: 0.833910048
#             y: 0.869037271
#           }
#           normalized_vertices {
#             x: 0.833910048
#             y: 0.876843035
#           }
#           normalized_vertices {
#             x: 0.813148797
#             y: 0.876843035
#           }
#         }
#       }
#     }
#     id: "38"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1522
#         end_index: 1526
#       }
#     }
#     type_: "quantity"
#     mention_text: "4.5V"
#     confidence: 0.829396605
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.468858123
#             y: 0.887684286
#           }
#           normalized_vertices {
#             x: 0.500576675
#             y: 0.887684286
#           }
#           normalized_vertices {
#             x: 0.500576675
#             y: 0.895923674
#           }
#           normalized_vertices {
#             x: 0.468858123
#             y: 0.895923674
#           }
#         }
#       }
#     }
#     id: "39"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1527
#         end_index: 1530
#       }
#     }
#     type_: "quantity"
#     mention_text: "1.0"
#     confidence: 0.753059804
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.683391
#             y: 0.886383355
#           }
#           normalized_vertices {
#             x: 0.701845467
#             y: 0.886383355
#           }
#           normalized_vertices {
#             x: 0.701845467
#             y: 0.893755436
#           }
#           normalized_vertices {
#             x: 0.683391
#             y: 0.893755436
#           }
#         }
#       }
#     }
#     id: "40"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1531
#         end_index: 1534
#       }
#     }
#     type_: "quantity"
#     mention_text: "3.0"
#     confidence: 0.840204954
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.815455616
#             y: 0.886383355
#           }
#           normalized_vertices {
#             x: 0.835640132
#             y: 0.886383355
#           }
#           normalized_vertices {
#             x: 0.835640132
#             y: 0.893755436
#           }
#           normalized_vertices {
#             x: 0.815455616
#             y: 0.893755436
#           }
#         }
#       }
#     }
#     id: "41"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1549
#         end_index: 1551
#       }
#     }
#     type_: "quantity"
#     mention_text: "40"
#     confidence: 0.827210069
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.749711633
#             y: 0.904163063
#           }
#           normalized_vertices {
#             x: 0.765859306
#             y: 0.904163063
#           }
#           normalized_vertices {
#             x: 0.765859306
#             y: 0.911535144
#           }
#           normalized_vertices {
#             x: 0.749711633
#             y: 0.911535144
#           }
#         }
#       }
#     }
#     id: "42"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1604
#         end_index: 1605
#       }
#     }
#     type_: "quantity"
#     mention_text: "0"
#     confidence: 0.895027041
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.375432521
#             y: 0.923677385
#           }
#           normalized_vertices {
#             x: 0.384659737
#             y: 0.923677385
#           }
#           normalized_vertices {
#             x: 0.384659737
#             y: 0.93148309
#           }
#           normalized_vertices {
#             x: 0.375432521
#             y: 0.93148309
#           }
#         }
#       }
#     }
#     id: "43"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1617
#         end_index: 1619
#       }
#     }
#     type_: "quantity"
#     mention_text: "20"
#     confidence: 0.66987884
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.758362174
#             y: 0.92194277
#           }
#           normalized_vertices {
#             x: 0.775086522
#             y: 0.92194277
#           }
#           normalized_vertices {
#             x: 0.775086522
#             y: 0.929314852
#           }
#           normalized_vertices {
#             x: 0.758362174
#             y: 0.929314852
#           }
#         }
#       }
#     }
#     id: "44"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1621
#         end_index: 1632
#       }
#     }
#     type_: "quantity"
#     mention_text: "3 Direction"
#     confidence: 0.473464489
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.0640138388
#             y: 0.941890717
#           }
#           normalized_vertices {
#             x: 0.118800461
#             y: 0.941890717
#           }
#           normalized_vertices {
#             x: 0.118800461
#             y: 0.949696422
#           }
#           normalized_vertices {
#             x: 0.0640138388
#             y: 0.949696422
#           }
#         }
#       }
#     }
#     id: "45"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1901
#         end_index: 1906
#       }
#     }
#     type_: "organization"
#     mention_text: "SHARP"
#     confidence: 0.439272046
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.224913493
#             y: 0.980052054
#           }
#           normalized_vertices {
#             x: 0.256055355
#             y: 0.980052054
#           }
#           normalized_vertices {
#             x: 0.256055355
#             y: 0.98915869
#           }
#           normalized_vertices {
#             x: 0.224913493
#             y: 0.98915869
#           }
#         }
#       }
#     }
#     id: "46"
#   }
#   properties {
#     text_anchor {
#       text_segments {
#         start_index: 1997
#         end_index: 2004
#       }
#     }
#     type_: "organization"
#     mention_text: "SHARP\'s"
#     confidence: 0.69332695
#     page_anchor {
#       page_refs {
#         bounding_poly {
#           normalized_vertices {
#             x: 0.618223786
#             y: 0.980052054
#           }
#           normalized_vertices {
#             x: 0.65743947
#             y: 0.980052054
#           }
#           normalized_vertices {
#             x: 0.65743947
#             y: 0.98915869
#           }
#           normalized_vertices {
#             x: 0.618223786
#             y: 0.98915869
#           }
#         }
#       }
#     }
#     id: "47"
#   }
# }
